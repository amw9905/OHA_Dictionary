# %%
df_admission_source <- data.frame(ADMSNSRC = c('1',
                                    '2',
                                    '4',
                                    '5',
                                    '6',
                                    '8',
                                    '9',
                                    'D',
                                    'E',
                                    'F',
                                    'N5',
                                    'N6',
                                    'Not Provided'),
                      Admission_Source = c('Non-health Care Facility Point of Origin',
                                    'Clinic or Physician\'s Office',
                                    'Transfer From a Hospital \\(Different Facility\\)',
                                    'Transfer From a Skilled Nursing Facility, Intermediate Care Facility, or Assisted Living Facility',
                                    'Transfer From Another Health Care Facility',
                                    'Court/Law Enforcement',
                                    'Information Not Available',
                                    'Transfer From One Distinct Unit of the Hospital to another Distinct Unit of the Same Hospital',
                                    'Transfer From Ambulatory Surgery Center',
                                    'Transfer From Hospice',
                                    'Born Inside this Hospital',
                                    'Born Outside this Hospital',
                                    'Information Not Available \\(Not Provided \\)'))

df_admission_type <-  data.frame(ADMSNTYPE = c('1',
                                    '2',
                                    '3',
                                    '4',
                                    '5',
                                    '9',
                                    'Not Provided'),
                                   Admission_Type = c('Emergency',
                                    'Urgent',
                                    'Elective',
                                    'Newborn',
                                    'Trauma',
                                    'Information Not Available',
                                    'Information Not Available \\(Not Provided\\)'))

df_discharge_status <- data.frame(DISCHGSTAT = as.character(c('01',
                                    '02',
                                    '03',
                                    '04',
                                    '05',
                                    '06',
                                    '07',
                                    '09',
                                    20,
                                    21,
                                    30,
                                    40,
                                    41,
                                    42,
                                    43,
                                    50,
                                    51,
                                    61,
                                    62,
                                    63,
                                    64,
                                    65,
                                    66,
                                    70,
                                    69,
                                    81,
                                    82,
                                    83,
                                    84,
                                    85,
                                    86,
                                    87,
                                    88,
                                    89,
                                    90,
                                    91,
                                    92,
                                    93,
                                    94,
                                    95,
                                    'Not Provided')),
                     Discharge_Status       = c('Discharged to Home or Self Care',
                                    'Discharged/transferred to Short Term Care',
                                    'Discharged/transferred to SNF',
                                    'Discharged/transferred to Intermediate Care',
                                    'Discharged/transferred to Cancer Center or Childrens Hospital',
                                    'Discharged/transferred to Home Health',
                                    'Left against Medical Advice',
                                    'Admitted as Inpatient',
                                    'Expired',
                                    'Discharged/transferred to court/law enforcement',
                                    'Still Patient',
                                    'Expired at Home',
                                    'Expired at Medical Facility',
                                    'Expired Place Unknown',
                                    'Discharged/transferred to Federal Hospital',
                                    'Discharged/transferred to Hospice Home',
                                    'Discharged/transferred to Hospice Medical Facility',
                                    'Discharged/transferred within Hospital to Medicare Swing Bed',
                                    'Discharged/transferred to Inpatient Rehab Facility',
                                    'Discharged/transferred to Medicare Long Term Care',
                                    'Discharged/transferred to Medicaid Long Term Care',
                                    'Discharged/transferred to Psychiatric Facility',
                                    'Discharged/transferred to a Critical Access Hospital',
                                    'Discharged/transferred to Other Institution',
                                    'Discharged/transferred to a Designated Disaster Alternative Care Site',
                                    'Discharged to Home or Self Care with Planned Readmission',
                                    'Discharged/transferred to Short Term Care with Planned Readmission',
                                    'Discharged/transferredto SNF with Planned Readmission',
                                    'Discharged/transferred to Intermediate Care with Planned Readmission',
                                    'Discharged/transferred to Cancer Center or Childrens Hospital with Planned Readmission',
                                    'Discharged/transferred to Home Health with Planned Readmission',
                                    'Discharged/transferred to court/law enforcement with Planned Readmission',
                                    'Discharged/transferred to Federal Hospital with Planned Readmission',
                                    'Discharged/transferred within Hospital to Medicare Swing Bed with Planned Readmission',
                                    'Discharged/transferred to Inpatient Rehab Facility with Planned Readmission',
                                    'Discharged/transferred to Medicare Long Term Care with Planned Readmission',
                                    'Discharged/transferred to Medicaid Long Term Care with Planned Readmission',
                                    'Discharged/transferred to Psychiatric Facility withPlanned Readmission',
                                    'Discharged/transferred to a Critical Access Hospital with Planned Readmission',
                                    'Discharged/transferred to Other Institution with Planned Readmission',
                                    'Not Provided'))

df_ecnounter_type <- data.frame(ENCOUNTERTYPEID = c('I','O'), Encounter_Type = c('Inpatient','Outpatient'))


df_ethnicity <- data.frame(ETHNICITY = c('1',
                                        '2',
                                        '3',
                                        '4',
                                        'Not Provided'),                        
                           Ethnicity_1 = c('Hispanic or Latino',
                                        'Non Hispanic or Latino',
                                        'Unavailable',
                                        'Declined',
                                        'Unavailable \\(Not Provided\\)'))

df_language <- data.frame(LANGUAGE = c("1","2","3","4","5","Not Provided"),
                          language_1 = c('English',"Spanish",'Other','Declined','Unavailable','Unavailable \\(Not Provided\\)'))

df_payer <- data.frame(PMTSRCE2 = c('A','B','C','D','E','F','I','M','O','Q','Not Provided'),
                      Payer_Type = c('Self Pay',
                                'Workers Compensation',
                                'Medicare',
                                'Medicaid',
                                'Other Government',
                                'Commercial Insurance',
                                'Other',
                                'Medicaid HMO',
                                'Medicare HMO',
                                'Charity Uncompensated',
                                'Not Provided'))


df_race <- data.frame(RACE = c('1',
                               '2',
                               '3',
                               '4',
                               '5',
                               '6',
                               '7',
                               '9',
                               'Not Provided'),                        
                           Race_1 = c('White or Caucasian',
                               'African American / Black',
                               'American Indian/Alaska Native',
                               'Asian',
                               'Native Hawaiian /Other Pacific Islander',
                               'Unavailable or Unknown',
                               'Hispanic/Latino',
                               'Declined',
                               'Unavailable \\(Not Provided\\)'))

df_sex <- data.frame(SEX = c('F',
                            'M',
                            'Not Provided',
                            'U'),
                     
                    Sex_1 = c('Female',
                               'Male',
                               'Unknown \\(Not Provided\\)',
                               'Unknown'))
